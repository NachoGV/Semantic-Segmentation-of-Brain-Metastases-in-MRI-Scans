# %% [markdown]
# # UNETR
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/NachoGV/semantic-Segmentation-of-Brain-Metastases-in-MRI-Scans/blob/main/models/UNETR.ipynb)

# %% [markdown]
# ## Environment Set Up

# %% [markdown]
# ## Requirements

# %%
# !pip install monai[einops]
# Out:
# Requirement already satisfied: monai[einops] in /usr/local/lib/python3.10/dist-packages (1.3.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from monai[einops]) (1.25.2)
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.10/dist-packages (from monai[einops]) (2.2.1+cu121)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from monai[einops]) (0.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai[einops]) (3.13.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai[einops]) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai[einops]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai[einops]) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai[einops]) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai[einops]) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai[einops]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai[einops]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai[einops]) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai[einops]) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai[einops]) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai[einops]) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai[einops]) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai[einops]) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai[einops]) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai[einops]) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai[einops]) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai[einops]) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.9->monai[einops]) (12.4.127)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.9->monai[einops]) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.9->monai[einops]) (1.3.0)

# %% [markdown]
# ### Colab Integration

# %%
# Set up Colab Workspace
from google.colab import drive

drive.mount('/content/drive', force_remount=True)

# !ln -s /content/drive/MyDrive/TFM/data /content/data
# !ln -s /content/drive/MyDrive/TFM/utils /content/utils
# !ln -s /content/drive/MyDrive/TFM/outputs /content/outputs
# Out:
# Mounted at /content/drive
#
# Copying utils files into workspace
#               0   0%    0.00kB/s    0:00:00 (xfr#0, to-chk=0/7)

# %% [markdown]
# ### Imports

# %%
# System
import os
import time
from math import nan

# Data Load & Visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Monai
from monai.data import DataLoader
from monai.losses import DiceLoss
from monai.metrics import DiceMetric
from monai.data import decollate_batch
from monai.utils import set_determinism
from monai.networks.nets import UNETR
from monai.handlers.utils import from_engine
from monai.inferers import sliding_window_inference

# PyTorch
import torch
from torch.utils.data import SequentialSampler

# Utils
from utils.Transforms import Transforms
from utils.plots import plot_gt_vs_pred
from utils.UCSF_Dataset import UCSF_Dataset

# %% [markdown]
# ### Config

# %%
# Check if CUDA is available
device = None
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("Running on GPU")
else:
    device = torch.device("cpu")
    print("Running on CPU")

# Print the device
print(f"Device: {device}")
# Out:
# Running on GPU
# Device: cuda

# %%
# Seeds
seed = 33
set_determinism(seed=seed) # Monai
np.random.seed(seed) # Numpy
torch.manual_seed(seed) # PyTorch

# Others
# %matplotlib inline
pd.set_option("display.max_columns", None)
model_name = "UNETR"

# %% [markdown]
# ## Load Data

# %%
# Load Subjects Information
train_df = pd.read_csv('data/TRAIN.csv')
val_df = pd.read_csv('data/VAL.csv')
test_df = pd.read_csv('data/TEST.csv')

# REMOVE
train_df = train_df.iloc[245:]
val_df = val_df.iloc[28:]
train_df.reset_index(drop=True, inplace=True)
val_df.reset_index(drop=True, inplace=True)

train_df.head()
# Out:
#   SubjectID     Sex CancerType          ScannerType In-plane voxel size (mm)  \
# 0   100381A    Male       Lung  GE 1.5 T Signa HDxt                0.86x0.86
# 1   100414B  Female     Breast  GE 1.5 T Signa HDxt                0.59x0.59
# 2   100132B    Male       Lung  GE 1.5 T Signa HDxt                  0.5x0.5
# 3   100212A  Female       Lung  GE 1.5 T Signa HDxt                1.17x1.17
# 4   100243B  Female     Breast  GE 1.5 T Signa HDxt                0.86x0.86
#
#    Matrix size Prior Craniotomy/Biopsy/Resection   Age  \
# 0  256x256x126                                No  71.0
# 1   512x512x50                                No  52.0
# 2  512x512x156                                No  55.0
# 3   256x256x98                                No  52.0
# 4  256x256x100                                No  55.0
#
#    Scanner Strength (Tesla)  Slice Thickness (mm)  NumberMetastases  \
# 0                       1.5                   1.5               4.0
# 1                       1.5                   3.0               5.0
# 2                       1.5                   1.2               5.0
# 3                       1.5                   1.5               9.0
# 4                       1.5                   1.5               6.0
#
#    VolumeMetastases_mm3  S-NM          S-V       S-VMax     S-VMin  \
# 0           3082.045582   4.0  3082.045541  2445.030377  77.549672
# 1             84.446590   5.0    84.446586    22.656401  11.328201
# 2            734.400029   5.0   734.400029   236.700009  81.300003
# 3            208.062478   9.0   208.062474    43.260514  16.480196
# 4            517.367105   6.0   517.367098   173.932836   8.862820
#
#       S-VMean      S-VStd       S-VDiff  \
# 0  770.511385  974.806455  4.146686e-05
# 1   16.889317    3.940386  3.629621e-06
# 2  146.880006   64.989060  1.136868e-13
# 3   23.118053    7.876000  3.481233e-06
# 4   86.227850   52.711028  6.960829e-06
#
#                                                T1pre  \
# 0  data/raw/UCSF_BrainMetastases_TRAIN/100381A/10...
# 1  data/raw/UCSF_BrainMetastases_TRAIN/100414B/10...
# 2  data/raw/UCSF_BrainMetastases_TRAIN/100132B/10...
# 3  data/raw/UCSF_BrainMetastases_TRAIN/100212A/10...
# 4  data/raw/UCSF_BrainMetastases_TRAIN/100243B/10...
#
#                                                FLAIR  \
# 0  data/raw/UCSF_BrainMetastases_TRAIN/100381A/10...
# 1  data/raw/UCSF_BrainMetastases_TRAIN/100414B/10...
# 2  data/raw/UCSF_BrainMetastases_TRAIN/100132B/10...
# 3  data/raw/UCSF_BrainMetastases_TRAIN/100212A/10...
# 4  data/raw/UCSF_BrainMetastases_TRAIN/100243B/10...
#
#                                               T1post  \
# 0  data/raw/UCSF_BrainMetastases_TRAIN/100381A/10...
# 1  data/raw/UCSF_BrainMetastases_TRAIN/100414B/10...
# 2  data/raw/UCSF_BrainMetastases_TRAIN/100132B/10...
# 3  data/raw/UCSF_BrainMetastases_TRAIN/100212A/10...
# 4  data/raw/UCSF_BrainMetastases_TRAIN/100243B/10...
#
#                                              T2Synth  \
# 0  data/raw/UCSF_BrainMetastases_TRAIN/100381A/10...
# 1  data/raw/UCSF_BrainMetastases_TRAIN/100414B/10...
# 2  data/raw/UCSF_BrainMetastases_TRAIN/100132B/10...
# 3  data/raw/UCSF_BrainMetastases_TRAIN/100212A/10...
# 4  data/raw/UCSF_BrainMetastases_TRAIN/100243B/10...
#
#                                                  Seg  \
# 0  data/raw/UCSF_BrainMetastases_TRAIN/100381A/10...
# 1  data/raw/UCSF_BrainMetastases_TRAIN/100414B/10...
# 2  data/raw/UCSF_BrainMetastases_TRAIN/100132B/10...
# 3  data/raw/UCSF_BrainMetastases_TRAIN/100212A/10...
# 4  data/raw/UCSF_BrainMetastases_TRAIN/100243B/10...
#
#                                            BraTS-seg
# 0  data/raw/UCSF_BrainMetastases_TRAIN/100381A/10...
# 1  data/raw/UCSF_BrainMetastases_TRAIN/100414B/10...
# 2  data/raw/UCSF_BrainMetastases_TRAIN/100132B/10...
# 3  data/raw/UCSF_BrainMetastases_TRAIN/100212A/10...
# 4  data/raw/UCSF_BrainMetastases_TRAIN/100243B/10...

# %%
b_size = 1
t_size = 3
v_size = 3
spatial_size = (240, 240, 160)

# %%
transforms = Transforms(seed)

# Train Dataset
train_images = [train_df['T1pre'], train_df['FLAIR'], train_df['T1post'], train_df['T2Synth']]
train_labels = train_df['BraTS-seg']
train_dataset = UCSF_Dataset(train_images, train_labels, transforms.train(spatial_size=spatial_size), t_size)

# Validation Dataset
val_images = [val_df['T1pre'], val_df['FLAIR'], val_df['T1post'], val_df['T2Synth']]
val_labels = val_df['BraTS-seg']
val_dataset = UCSF_Dataset(val_images, val_labels, transforms.val(), v_size)

# Samplers
train_sampler = SequentialSampler(train_dataset)
val_sampler = SequentialSampler(val_dataset)

# DataLoaders
train_loader = DataLoader(train_dataset, batch_size=b_size, shuffle=False, sampler=train_sampler)
val_loader = DataLoader(val_dataset, batch_size=1, shuffle=False, sampler=val_sampler)

# %% [markdown]
# ## Training

# %% [markdown]
# ### Parameters

# %%
# Training
max_epochs = 100
VAL_AMP = True
lr = 1e-4
weight_decay = 1e-5

# Report Frequency
plt_imgs = []
val_interval = 1
plot_interval = 1
best_metric_update = False
max_step = len(train_dataset) // train_loader.batch_size - 1
max_val_step = len(val_dataset) // val_loader.batch_size - 3

# Metrics Storages
best_metric = -1
best_metric_epoch = -1
best_metrics_epochs_and_time = [[], [], []]
epoch_loss_values = []
val_loss_values = []
metric_values = []
metric_values_tc = []
metric_values_wt = []
metric_values_et = []
with open(f"outputs/{model_name}/{model_name}_metrics.csv", "a") as f:
  f.write(f"epoch,metric,metric_tc,metric_wt,metric_et,train_loss,val_loss\n")

# %% [markdown]
# ### Create Model, Loss, Optimizer

# %%
# Model
model = UNETR(
    in_channels=4,
    out_channels=3,
    dropout_rate=0.2,
    img_size=spatial_size,
    spatial_dims=3,
    hidden_size=768,
    mlp_dim=3072,
    num_heads=12
).to(device)

# Loss Function
loss_function = DiceLoss(smooth_nr=1e-5, smooth_dr=1e-5, squared_pred=True, to_onehot_y=False, sigmoid=True)

# Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr, weight_decay=weight_decay)
lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=max_epochs)

# Metrics
dice_metric = DiceMetric(include_background=True, reduction="mean")
dice_metric_batch = DiceMetric(include_background=True, reduction="mean_batch")

# Inference Method
def inference(input):
    def _compute(input):
        return sliding_window_inference(
            inputs=input,
            roi_size=spatial_size,
            sw_batch_size=1,
            predictor=model,
            overlap=0.5,
        )

    if VAL_AMP:
        with torch.cuda.amp.autocast():
            return _compute(input)
    else:
        return _compute(input)

# AMP to accelerate training
scaler = torch.cuda.amp.GradScaler()

# enable cuDNN benchmark
torch.backends.cudnn.benchmark = True

# %% [markdown]
# ### Execute a typical PyTorch training process

# %%
total_start = time.time()
for epoch in range(max_epochs):
    epoch_start = time.time()
    print("-" * 10)
    print(f"epoch {epoch + 1}/{max_epochs}")

    # TRAINING
    model.train()
    epoch_loss = 0
    step = 0
    print('TRAIN')
    for batch_data in train_loader:
        step_start = time.time()
        step += 1
        inputs, labels = (
            batch_data["image"].to(device),
            batch_data["label"].to(device),
        )
        optimizer.zero_grad()
        with torch.cuda.amp.autocast():
            outputs = model(inputs)
            loss = loss_function(outputs, labels)
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        epoch_loss += loss.item()

        print(f"   Batch {step}/{len(train_dataset) // train_loader.batch_size}"
              f", train_loss: {loss.item():.4f}"
              f", step time: {(time.time() - step_start):.4f}")

        # Store the image to plot
        if step == max_step:
          plt_imgs = [labels[0], transforms.post()(outputs[0])]

    lr_scheduler.step()
    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)

    # Plot the Img
    if (epoch + 1) % plot_interval == 0:
      plot_gt_vs_pred(plt_imgs[0], plt_imgs[1], True)

    # VALIDATION
    print('VAL')
    val_loss = 0
    val_step = 0
    if (epoch + 1) % val_interval == 0:
        model.eval()
        with torch.no_grad():
            best_val_dice = -1
            for val_data in val_loader:
                val_inputs, val_labels = (
                    val_data["image"].to(device),
                    val_data["label"].to(device),
                )
                val_step += 1
                val_outputs = inference(val_inputs)
                loss_value = loss_function(val_outputs[0], val_labels[0])
                val_loss += loss_value.item()

                val_outputs = [transforms.post()(x) for x in val_outputs]

                dice_metric(y_pred=val_outputs, y=val_labels)
                dice_metric_batch(y_pred=val_outputs, y=val_labels)

                print(f"   Batch {val_step}/{len(val_dataset) // val_loader.batch_size}"
                      f", val_loss: {loss_value.item():.4f}")

                # Store plot image
                if val_step == max_val_step:
                  plt_imgs = [val_labels[0], val_outputs[0]]

            val_loss /= val_step
            val_loss_values.append(val_loss)

            # Plot the img
            if (epoch + 1) % plot_interval == 0:
              plot_gt_vs_pred(plt_imgs[0], plt_imgs[1], False)

            metric = dice_metric.aggregate().item()
            metric_values.append(metric)
            metric_batch = dice_metric_batch.aggregate()
            metric_tc = metric_batch[0].item()
            metric_values_tc.append(metric_tc)
            metric_wt = metric_batch[1].item()
            metric_values_wt.append(metric_wt)
            metric_et = metric_batch[2].item()
            metric_values_et.append(metric_et)
            dice_metric.reset()
            dice_metric_batch.reset()

            if metric > best_metric:
                best_metric = metric
                best_metric_epoch = epoch + 1
                best_metrics_epochs_and_time[0].append(best_metric)
                best_metrics_epochs_and_time[1].append(best_metric_epoch)
                best_metrics_epochs_and_time[2].append(time.time() - total_start)
                torch.save(
                    model.state_dict(),
                    os.path.join(f"outputs/{model_name}/{model_name}_{epoch+1}.pth"),
                )
                best_metric_update = True

            # Save all metrics in csv
            with open(f"outputs/{model_name}/{model_name}_metrics.csv", "a") as f:
                f.write(f"{epoch + 1},{metric},{metric_tc},{metric_wt},{metric_et},{epoch_loss},{val_loss}\n")

    # REPORT
    print(f"epoch {epoch + 1}\n"
          f"   average train loss: {epoch_loss:.4f}\n"
          f"   average validation loss: {val_loss:.4f}\n"
          f"   saved as best model: {best_metric_update}\n"
          f"   current mean dice: {metric_values[-1]:.4f}\n"
          f"   current TC dice: {metric_values_tc[-1]:.4f}\n"
          f"   current WT dice: {metric_values_wt[-1]:.4f}\n"
          f"   current ET dice: {metric_values_et[-1]:.4f}")
    print(f"Best Mean Metric: {best_metric:.4f}")
    print(f"time consuming of epoch {epoch + 1} is: {(time.time() - epoch_start):.4f}")
    best_metric_update = False

    # When epoch ends, clean GPU memory
    torch.cuda.empty_cache()

total_time = time.time() - total_start
# Out:
# ----------
# epoch 1/10
# 1/10, train_loss: 1.0000, step time: 14.9489
# 2/10, train_loss: 0.9975, step time: 1.4145
# 3/10, train_loss: 0.9995, step time: 1.4052
# 4/10, train_loss: 0.9969, step time: 1.3898
# 5/10, train_loss: 0.9989, step time: 1.3678
# 6/10, train_loss: 0.9910, step time: 1.3668
# 7/10, train_loss: 0.9674, step time: 1.3727
# 8/10, train_loss: 0.9471, step time: 1.3967
# 9/10, train_loss: 0.9678, step time: 1.3833
# 10/10, train_loss: 0.9999, step time: 1.3795
# epoch 1 average loss: 0.9866
# saved new best metric model
# current epoch: 1 current mean dice: 0.0225 tc: 0.0276 wt: 0.0362 et: 0.0046
# best mean dice: 0.0225 at epoch: 1
# time consuming of epoch 1 is: 186.9205
# ----------
# epoch 2/10
# 1/10, train_loss: 0.9987, step time: 1.4385
# 2/10, train_loss: 0.9960, step time: 1.4441
# 3/10, train_loss: 0.9999, step time: 1.3821
# 4/10, train_loss: 0.9576, step time: 1.4074
# 5/10, train_loss: 0.9350, step time: 1.4319
# 6/10, train_loss: 0.9999, step time: 1.3808
# 7/10, train_loss: 0.9873, step time: 1.4259
# 8/10, train_loss: 0.9593, step time: 1.4160
# 9/10, train_loss: 0.9962, step time: 1.4065
# 10/10, train_loss: 0.9991, step time: 1.3998
# epoch 2 average loss: 0.9829
# saved new best metric model
# current epoch: 2 current mean dice: 0.0278 tc: 0.0372 wt: 0.0421 et: 0.0051
# best mean dice: 0.0278 at epoch: 2
# time consuming of epoch 2 is: 173.1724
# ----------
# epoch 3/10
# 1/10, train_loss: 0.9280, step time: 1.5119
# 2/10, train_loss: 0.9991, step time: 1.4399
# 3/10, train_loss: 0.9571, step time: 1.4470
# 4/10, train_loss: 0.9862, step time: 1.4302
# 5/10, train_loss: 0.9953, step time: 1.4218
# 6/10, train_loss: 0.9494, step time: 1.4496
# 7/10, train_loss: 0.9999, step time: 1.4098
# 8/10, train_loss: 0.9984, step time: 1.4446
# 9/10, train_loss: 0.9958, step time: 1.4270
# 10/10, train_loss: 0.9999, step time: 1.4180
# epoch 3 average loss: 0.9809
# saved new best metric model
# current epoch: 3 current mean dice: 0.0307 tc: 0.0384 wt: 0.0495 et: 0.0053
# best mean dice: 0.0307 at epoch: 3
# time consuming of epoch 3 is: 167.1167
# ----------
# epoch 4/10
# 1/10, train_loss: 0.9959, step time: 1.4708
# 2/10, train_loss: 0.9551, step time: 1.4763
# 3/10, train_loss: 0.9999, step time: 1.4277
# 4/10, train_loss: 0.9856, step time: 1.4412
# 5/10, train_loss: 0.9218, step time: 1.4425
# 6/10, train_loss: 0.9472, step time: 1.4579
# 7/10, train_loss: 0.9990, step time: 1.4261
# 8/10, train_loss: 0.9949, step time: 1.4178
# 9/10, train_loss: 0.9999, step time: 1.4288
# 10/10, train_loss: 0.9983, step time: 1.4417
# epoch 4 average loss: 0.9798
# saved new best metric model
# current epoch: 4 current mean dice: 0.0337 tc: 0.0402 wt: 0.0565 et: 0.0053
# best mean dice: 0.0337 at epoch: 4
# time consuming of epoch 4 is: 169.2094
# ----------
# epoch 5/10
# 1/10, train_loss: 0.9957, step time: 1.4808
# 2/10, train_loss: 0.9538, step time: 1.4552
# 3/10, train_loss: 0.9197, step time: 1.4499
# 4/10, train_loss: 0.9983, step time: 1.4534
# 5/10, train_loss: 0.9853, step time: 1.4476
# 6/10, train_loss: 0.9948, step time: 1.4222
# 7/10, train_loss: 0.9999, step time: 1.4152
# 8/10, train_loss: 0.9452, step time: 1.4441
# 9/10, train_loss: 0.9999, step time: 1.4072
# 10/10, train_loss: 0.9990, step time: 1.4421
# epoch 5 average loss: 0.9792
# saved new best metric model
# current epoch: 5 current mean dice: 0.0347 tc: 0.0407 wt: 0.0591 et: 0.0053
# best mean dice: 0.0347 at epoch: 5
# time consuming of epoch 5 is: 171.4466
# ----------
# epoch 6/10
# 1/10, train_loss: 0.9446, step time: 1.4658
# 2/10, train_loss: 0.9982, step time: 1.4303
# 3/10, train_loss: 0.9990, step time: 1.3847
# 4/10, train_loss: 0.9525, step time: 1.4164
# 5/10, train_loss: 0.9171, step time: 1.4083
# 6/10, train_loss: 0.9946, step time: 1.3834
# 7/10, train_loss: 0.9999, step time: 1.4685
# 8/10, train_loss: 0.9999, step time: 1.3970
# 9/10, train_loss: 0.9953, step time: 1.3965
# 10/10, train_loss: 0.9847, step time: 1.4062
# epoch 6 average loss: 0.9786
# saved new best metric model
# current epoch: 6 current mean dice: 0.0356 tc: 0.0412 wt: 0.0613 et: 0.0053
# best mean dice: 0.0356 at epoch: 6
# time consuming of epoch 6 is: 174.9252
# ----------
# epoch 7/10
# 1/10, train_loss: 0.9518, step time: 1.4261
# 2/10, train_loss: 0.9159, step time: 1.4235
# 3/10, train_loss: 0.9981, step time: 1.3709
# 4/10, train_loss: 0.9432, step time: 1.4022
# 5/10, train_loss: 0.9946, step time: 1.3975
# 6/10, train_loss: 0.9847, step time: 1.3660
# 7/10, train_loss: 0.9999, step time: 1.3723
# 8/10, train_loss: 0.9999, step time: 1.3703
# 9/10, train_loss: 0.9952, step time: 1.3713
# 10/10, train_loss: 0.9990, step time: 1.3846
# epoch 7 average loss: 0.9782
# saved new best metric model
# current epoch: 7 current mean dice: 0.0362 tc: 0.0413 wt: 0.0629 et: 0.0053
# best mean dice: 0.0362 at epoch: 7
# time consuming of epoch 7 is: 170.8963
# ----------
# epoch 8/10
# 1/10, train_loss: 0.9999, step time: 1.4194
# 2/10, train_loss: 0.9999, step time: 16.7175
# 3/10, train_loss: 0.9845, step time: 2.2112
# 4/10, train_loss: 0.9146, step time: 2.2046
# 5/10, train_loss: 0.9944, step time: 2.2052
# 6/10, train_loss: 0.9425, step time: 2.1852
# 7/10, train_loss: 0.9951, step time: 2.1862
# 8/10, train_loss: 0.9990, step time: 2.1752
# 9/10, train_loss: 0.9508, step time: 2.1926
# 10/10, train_loss: 0.9981, step time: 2.1825
# epoch 8 average loss: 0.9779
# saved new best metric model
# current epoch: 8 current mean dice: 0.0365 tc: 0.0416 wt: 0.0638 et: 0.0054
# best mean dice: 0.0365 at epoch: 8
# time consuming of epoch 8 is: 192.6776
# ----------
# epoch 9/10
# 1/10, train_loss: 0.9999, step time: 2.2441
# 2/10, train_loss: 0.9507, step time: 2.2225
# 3/10, train_loss: 0.9944, step time: 2.2350
# 4/10, train_loss: 0.9952, step time: 2.2499
# 5/10, train_loss: 0.9141, step time: 2.2358
# 6/10, train_loss: 0.9990, step time: 2.2291
# 7/10, train_loss: 0.9421, step time: 2.2688
# 8/10, train_loss: 0.9981, step time: 2.2469
# 9/10, train_loss: 0.9843, step time: 2.3041
# 10/10, train_loss: 0.9999, step time: 2.2357
# epoch 9 average loss: 0.9778
# saved new best metric model
# current epoch: 9 current mean dice: 0.0368 tc: 0.0417 wt: 0.0643 et: 0.0054
# best mean dice: 0.0368 at epoch: 9
# time consuming of epoch 9 is: 170.9534
# ----------
# epoch 10/10
# 1/10, train_loss: 0.9999, step time: 2.2662
# 2/10, train_loss: 0.9137, step time: 2.2994
# 3/10, train_loss: 0.9999, step time: 2.2647
# 4/10, train_loss: 0.9990, step time: 2.2694
# 5/10, train_loss: 0.9419, step time: 2.2824
# 6/10, train_loss: 0.9952, step time: 2.2762
# 7/10, train_loss: 0.9505, step time: 2.2848
# 8/10, train_loss: 0.9981, step time: 2.2989
# 9/10, train_loss: 0.9944, step time: 2.2982
# 10/10, train_loss: 0.9843, step time: 2.2807
# epoch 10 average loss: 0.9777
# saved new best metric model
# current epoch: 10 current mean dice: 0.0368 tc: 0.0417 wt: 0.0644 et: 0.0054
# best mean dice: 0.0368 at epoch: 10
# time consuming of epoch 10 is: 171.9741

# %%
print(f"train completed, best_metric: {best_metric:.4f} at epoch: {best_metric_epoch}, total time: {total_time}.")
# Out:
# train completed, best_metric: 0.0368 at epoch: 10, total time: 1749.7454869747162.

# %% [markdown]
# ### Plot the loss and metric

# %%
plt.figure("train", (10, 5))
plt.subplot(1, 2, 1)
plt.title("Epoch Average Loss")
x = [i + 1 for i in range(len(epoch_loss_values))]
plt.xlabel("epoch")
plt.plot(x, epoch_loss_values)
plt.plot(x, val_loss_values)
plt.subplot(1, 2, 2)
plt.title("Val Mean Dice")
x = [val_interval * (i + 1) for i in range(len(metric_values))]
y = metric_values
plt.xlabel("epoch")
plt.plot(x, y, color="green")
plt.show()

plt.figure("train", (15, 5))
plt.subplot(1, 3, 1)
plt.title("Val Mean Dice TC")
x = [val_interval * (i + 1) for i in range(len(metric_values_tc))]
y = metric_values_tc
plt.xlabel("epoch")
plt.plot(x, y, color="blue")
plt.subplot(1, 3, 2)
plt.title("Val Mean Dice WT")
x = [val_interval * (i + 1) for i in range(len(metric_values_wt))]
y = metric_values_wt
plt.xlabel("epoch")
plt.plot(x, y, color="brown")
plt.subplot(1, 3, 3)
plt.title("Val Mean Dice ET")
x = [val_interval * (i + 1) for i in range(len(metric_values_et))]
y = metric_values_et
plt.xlabel("epoch")
plt.plot(x, y, color="purple")
plt.show()
